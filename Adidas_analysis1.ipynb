# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df=pd.read_excel(r"E:\Project\Adidas US Sales Datasets.xlsx")

# %%
df.head(5)
# Out:
#    Unnamed: 0   Unnamed: 1             Unnamed: 2           Unnamed: 3  \
# 0         NaN          NaN  Adidas Sales Database                  NaN
# 1         NaN          NaN                    NaN                  NaN
# 2         NaN          NaN                    NaN                  NaN
# 3         NaN     Retailer            Retailer ID         Invoice Date
# 4         NaN  Foot Locker                1185732  2020-01-01 00:00:00
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6             Unnamed: 7      Unnamed: 8  \
# 0        NaN        NaN        NaN                    NaN             NaN
# 1        NaN        NaN        NaN                    NaN             NaN
# 2        NaN        NaN        NaN                    NaN             NaN
# 3     Region      State       City                Product  Price per Unit
# 4  Northeast   New York   New York  Men's Street Footwear              50
#
#    Unnamed: 9  Unnamed: 10       Unnamed: 11       Unnamed: 12   Unnamed: 13
# 0         NaN          NaN               NaN               NaN           NaN
# 1         NaN          NaN               NaN               NaN           NaN
# 2         NaN          NaN               NaN               NaN           NaN
# 3  Units Sold  Total Sales  Operating Profit  Operating Margin  Sales Method
# 4        1200       600000            300000               0.5      In-store

# %%
df.columns = df.iloc[3]
df
# Out:
# 3     NaN     Retailer            Retailer ID         Invoice Date     Region  \
# 0     NaN          NaN  Adidas Sales Database                  NaN        NaN
# 1     NaN          NaN                    NaN                  NaN        NaN
# 2     NaN          NaN                    NaN                  NaN        NaN
# 3     NaN     Retailer            Retailer ID         Invoice Date     Region
# 4     NaN  Foot Locker                1185732  2020-01-01 00:00:00  Northeast
# ...   ...          ...                    ...                  ...        ...
# 9647  NaN  Foot Locker                1185732  2021-01-24 00:00:00  Northeast
# 9648  NaN  Foot Locker                1185732  2021-01-24 00:00:00  Northeast
# 9649  NaN  Foot Locker                1185732  2021-02-22 00:00:00  Northeast
# 9650  NaN  Foot Locker                1185732  2021-02-22 00:00:00  Northeast
# 9651  NaN  Foot Locker                1185732  2021-02-22 00:00:00  Northeast
#
# 3             State        City                  Product  Price per Unit  \
# 0               NaN         NaN                      NaN             NaN
# 1               NaN         NaN                      NaN             NaN
# 2               NaN         NaN                      NaN             NaN
# 3             State        City                  Product  Price per Unit
# 4          New York    New York    Men's Street Footwear              50
# ...             ...         ...                      ...             ...
# 9647  New Hampshire  Manchester            Men's Apparel              50
# 9648  New Hampshire  Manchester          Women's Apparel              41
# 9649  New Hampshire  Manchester    Men's Street Footwear              41
# 9650  New Hampshire  Manchester  Men's Athletic Footwear              42
# 9651  New Hampshire  Manchester  Women's Street Footwear              29
#
# 3     Units Sold  Total Sales  Operating Profit  Operating Margin  \
# 0            NaN          NaN               NaN               NaN
# 1            NaN          NaN               NaN               NaN
# 2            NaN          NaN               NaN               NaN
# 3     Units Sold  Total Sales  Operating Profit  Operating Margin
# 4           1200       600000            300000               0.5
# ...          ...          ...               ...               ...
# 9647          64         3200             896.0              0.28
# 9648         105         4305            1377.6              0.32
# 9649         184         7544           2791.28              0.37
# 9650          70         2940            1234.8              0.42
# 9651          83         2407            649.89              0.27
#
# 3     Sales Method
# 0              NaN
# 1              NaN
# 2              NaN
# 3     Sales Method
# 4         In-store
# ...            ...
# 9647        Outlet
# 9648        Outlet
# 9649        Outlet
# 9650        Outlet
# 9651        Outlet
#
# [9652 rows x 14 columns]

# %%
df = df.iloc[5:]
df = df.copy()

df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
# 3     NaN     Retailer Retailer ID         Invoice Date     Region  \
# 0     NaN  Foot Locker     1185732  2020-01-02 00:00:00  Northeast
# 1     NaN  Foot Locker     1185732  2020-01-03 00:00:00  Northeast
# 2     NaN  Foot Locker     1185732  2020-01-04 00:00:00  Northeast
# 3     NaN  Foot Locker     1185732  2020-01-05 00:00:00  Northeast
# 4     NaN  Foot Locker     1185732  2020-01-06 00:00:00  Northeast
# ...   ...          ...         ...                  ...        ...
# 9642  NaN  Foot Locker     1185732  2021-01-24 00:00:00  Northeast
# 9643  NaN  Foot Locker     1185732  2021-01-24 00:00:00  Northeast
# 9644  NaN  Foot Locker     1185732  2021-02-22 00:00:00  Northeast
# 9645  NaN  Foot Locker     1185732  2021-02-22 00:00:00  Northeast
# 9646  NaN  Foot Locker     1185732  2021-02-22 00:00:00  Northeast
#
# 3             State        City                    Product Price per Unit  \
# 0          New York    New York    Men's Athletic Footwear             50
# 1          New York    New York    Women's Street Footwear             40
# 2          New York    New York  Women's Athletic Footwear             45
# 3          New York    New York              Men's Apparel             60
# 4          New York    New York            Women's Apparel             50
# ...             ...         ...                        ...            ...
# 9642  New Hampshire  Manchester              Men's Apparel             50
# 9643  New Hampshire  Manchester            Women's Apparel             41
# 9644  New Hampshire  Manchester      Men's Street Footwear             41
# 9645  New Hampshire  Manchester    Men's Athletic Footwear             42
# 9646  New Hampshire  Manchester    Women's Street Footwear             29
#
# 3    Units Sold Total Sales Operating Profit Operating Margin Sales Method
# 0          1000      500000           150000              0.3     In-store
# 1          1000      400000           140000             0.35     In-store
# 2           850      382500           133875             0.35     In-store
# 3           900      540000           162000              0.3     In-store
# 4          1000      500000           125000             0.25     In-store
# ...         ...         ...              ...              ...          ...
# 9642         64        3200            896.0             0.28       Outlet
# 9643        105        4305           1377.6             0.32       Outlet
# 9644        184        7544          2791.28             0.37       Outlet
# 9645         70        2940           1234.8             0.42       Outlet
# 9646         83        2407           649.89             0.27       Outlet
#
# [9647 rows x 14 columns]

# %%
df.dropna(how='all', inplace=True)

df.dropna(axis=1, how='all', inplace=True)

# %%
df
# Out:
# 3        Retailer Retailer ID         Invoice Date     Region          State  \
# 0     Foot Locker     1185732  2020-01-02 00:00:00  Northeast       New York
# 1     Foot Locker     1185732  2020-01-03 00:00:00  Northeast       New York
# 2     Foot Locker     1185732  2020-01-04 00:00:00  Northeast       New York
# 3     Foot Locker     1185732  2020-01-05 00:00:00  Northeast       New York
# 4     Foot Locker     1185732  2020-01-06 00:00:00  Northeast       New York
# ...           ...         ...                  ...        ...            ...
# 9642  Foot Locker     1185732  2021-01-24 00:00:00  Northeast  New Hampshire
# 9643  Foot Locker     1185732  2021-01-24 00:00:00  Northeast  New Hampshire
# 9644  Foot Locker     1185732  2021-02-22 00:00:00  Northeast  New Hampshire
# 9645  Foot Locker     1185732  2021-02-22 00:00:00  Northeast  New Hampshire
# 9646  Foot Locker     1185732  2021-02-22 00:00:00  Northeast  New Hampshire
#
# 3           City                    Product Price per Unit Units Sold  \
# 0       New York    Men's Athletic Footwear             50       1000
# 1       New York    Women's Street Footwear             40       1000
# 2       New York  Women's Athletic Footwear             45        850
# 3       New York              Men's Apparel             60        900
# 4       New York            Women's Apparel             50       1000
# ...          ...                        ...            ...        ...
# 9642  Manchester              Men's Apparel             50         64
# 9643  Manchester            Women's Apparel             41        105
# 9644  Manchester      Men's Street Footwear             41        184
# 9645  Manchester    Men's Athletic Footwear             42         70
# 9646  Manchester    Women's Street Footwear             29         83
#
# 3    Total Sales Operating Profit Operating Margin Sales Method
# 0         500000           150000              0.3     In-store
# 1         400000           140000             0.35     In-store
# 2         382500           133875             0.35     In-store
# 3         540000           162000              0.3     In-store
# 4         500000           125000             0.25     In-store
# ...          ...              ...              ...          ...
# 9642        3200            896.0             0.28       Outlet
# 9643        4305           1377.6             0.32       Outlet
# 9644        7544          2791.28             0.37       Outlet
# 9645        2940           1234.8             0.42       Outlet
# 9646        2407           649.89             0.27       Outlet
#
# [9647 rows x 13 columns]

# %%
df.columns = (
    df.columns
      .astype(str)
      .str.strip()
      .str.replace(" ", "_")
      .str.lower()
)

print(df.columns)
# Out:
# Index(['retailer', 'retailer_id', 'invoice_date', 'region', 'state', 'city',
#        'product', 'price_per_unit', 'units_sold', 'total_sales',
#        'operating_profit', 'operating_margin', 'sales_method'],
#       dtype='object', name=3)

# %%
print(df.dtypes)
# Out:
# 3
# retailer            object
# retailer_id         object
# invoice_date        object
# region              object
# state               object
# city                object
# product             object
# price_per_unit      object
# units_sold          object
# total_sales         object
# operating_profit    object
# operating_margin    object
# sales_method        object
# dtype: object

# %%
df['invoice_date'] = pd.to_datetime(
    df['invoice_date'],
    errors='coerce'
)

numeric_cols = [
    'price_per_unit',
    'units_sold',
    'total_sales',
    'operating_profit',
    'operating_margin'
]

for col in numeric_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
df.head(3)
# Out:
# 3     retailer retailer_id invoice_date     region     state      city  \
# 0  Foot Locker     1185732   2020-01-02  Northeast  New York  New York
# 1  Foot Locker     1185732   2020-01-03  Northeast  New York  New York
# 2  Foot Locker     1185732   2020-01-04  Northeast  New York  New York
#
# 3                    product  price_per_unit  units_sold  total_sales  \
# 0    Men's Athletic Footwear            50.0        1000     500000.0
# 1    Women's Street Footwear            40.0        1000     400000.0
# 2  Women's Athletic Footwear            45.0         850     382500.0
#
# 3  operating_profit  operating_margin sales_method
# 0          150000.0              0.30     In-store
# 1          140000.0              0.35     In-store
# 2          133875.0              0.35     In-store

# %%
print(df.isnull().sum())

df.dropna(inplace=True)
# Out:
# 3
# retailer            0
# retailer_id         0
# invoice_date        0
# region              0
# state               0
# city                0
# product             0
# price_per_unit      0
# units_sold          0
# total_sales         0
# operating_profit    0
# operating_margin    0
# sales_method        0
# dtype: int64

# %%
print(df.duplicated().sum())

df.drop_duplicates(inplace=True)
# Out:
# 0

# %%
df['year'] = df['invoice_date'].dt.year
df['month'] = df['invoice_date'].dt.month
df['profit_per_unit'] = df['operating_profit'] / df['units_sold']

df.head(2)
# Out:
# 3     retailer retailer_id invoice_date     region     state      city  \
# 0  Foot Locker     1185732   2020-01-02  Northeast  New York  New York
# 1  Foot Locker     1185732   2020-01-03  Northeast  New York  New York
#
# 3                  product  price_per_unit  units_sold  total_sales  \
# 0  Men's Athletic Footwear            50.0        1000     500000.0
# 1  Women's Street Footwear            40.0        1000     400000.0
#
# 3  operating_profit  operating_margin sales_method  year  month  \
# 0          150000.0              0.30     In-store  2020      1
# 1          140000.0              0.35     In-store  2020      1
#
# 3  profit_per_unit
# 0            150.0
# 1            140.0

# %%
df.describe()

df['region'].value_counts()

df.groupby('product')['total_sales'].sum()

plt.hist(df['total_sales'])
plt.show()

# %%
df.head(5)
# Out:
# 3     retailer retailer_id invoice_date     region     state      city  \
# 0  Foot Locker     1185732   2020-01-07  Northeast  New York  New York
# 1  Foot Locker     1185732   2020-01-08  Northeast  New York  New York
# 2  Foot Locker     1185732   2020-01-21  Northeast  New York  New York
# 3  Foot Locker     1185732   2020-01-22  Northeast  New York  New York
# 4  Foot Locker     1185732   2020-01-23  Northeast  New York  New York
#
# 3                    product  price_per_unit  units_sold  total_sales  \
# 0      Men's Street Footwear            50.0        1250     625000.0
# 1    Men's Athletic Footwear            50.0         900     450000.0
# 2    Women's Street Footwear            40.0         950     380000.0
# 3  Women's Athletic Footwear            45.0         825     371250.0
# 4              Men's Apparel            60.0         900     540000.0
#
# 3  operating_profit  operating_margin sales_method  year  month month_name  \
# 0          312500.0              0.50     In-store  2020      1    January
# 1          135000.0              0.30       Outlet  2020      1    January
# 2          133000.0              0.35       Outlet  2020      1    January
# 3          129937.5              0.35       Outlet  2020      1    January
# 4          162000.0              0.30       Outlet  2020      1    January
#
# 3  quarter  profit_per_unit
# 0        1            250.0
# 1        1            150.0
# 2        1            140.0
# 3        1            157.5
# 4        1            180.0

# %%
df.to_excel(
    "clean_Adidas_Sales.xlsx",
    index=False
)
